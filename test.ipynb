# %%
using Pkg

# %%
Pkg.activate("../LinearSolve.jl")
Pkg.instantiate()
# Out:
#   Activating project at `d:\CU_Boulder_2023-2027\Fall_2025\CSCI3656_NumComp\LinearSolve.jl`

# %%
Pkg.test("LinearSolve")
# Out:
#      Testing LinearSolve
#       Status `C:\Users\jelly\AppData\Local\Temp\jl_IAnQps\Project.toml`
#   [9b6a8646] AllocCheck v0.2.2
#   [4c88cf16] Aqua v0.8.14
#   [4fba245c] ArrayInterface v7.21.0
#   [aae01518] BandedMatrices v1.9.5
#   [0a1fb500] BlockDiagonals v0.2.0
#   [d360d2e6] ChainRulesCore v1.26.0
#   [60701a23] CliqueTrees v1.12.1
#   [2569d6c7] ConcreteStructs v0.2.3
#   [ffbed154] DocStringExtensions v0.9.5
#   [4e289a0a] EnumX v1.0.5
#   [7d51a73a] ExplicitImports v1.13.2
#   [9d29842c] FastAlmostBandedMatrices v0.1.5
#   [29a986be] FastLapackInterface v2.0.4
#   [6a86dc24] FiniteDiff v2.29.0
#   [f6369f11] ForwardDiff v1.2.2
#   [46192b85] GPUArraysCore v0.2.0
#   [b5ffcf37] HYPRE v1.7.0
#   [42fd0dbc] IterativeSolvers v0.9.4
#   [ba0b0d4f] Krylov v0.10.2
#   [0b1a1467] KrylovKit v0.10.2
#   [45d422c2] KrylovPreconditioners v0.3.6
#   [5078a376] LazyArrays v2.8.0
#   [7ed4a6bd] LinearSolve v3.44.0 `D:\CU_Boulder_2023-2027\Fall_2025\CSCI3656_NumComp\LinearSolve.jl`
# ...

# %%
import LinearSolve as LS
import LinearAlgebra as LA

n = 4
A = rand(n, n)
b1 = rand(n);
prob = LS.LinearProblem(A, b1)
@show A

linsolve = LS.init(prob)
sol1 = LS.solve!(linsolve)
# Out:
# A = [0.18498298634395693 0.09988356583259828 0.9876866727434976 0.798904331656754; 0.4629558759577541 0.019045926039713 0.9559063739619222 0.6700563876513781; 0.16766385001969153 0.3778597866854534 0.35786575300393575 0.9543281191542843; 0.5382460531065216 0.33875773232633644 0.05228366833143194 0.1901129886861067]
# retcode: Success
# u: 4-element Vector{Float64}:
#   0.25326738274356964
#   2.4189989935762606
#   1.0403738218406768
#  -0.4452696812800888

# %%
A = [1 2; 3 4]
# Out:
# 2×2 Matrix{Int64}:
#  1  2
#  3  4
