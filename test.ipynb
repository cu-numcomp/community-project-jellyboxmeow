# %%
using Pkg

Pkg.add("RecursiveFactorization")
using RecursiveFactorization
# Pkg.add("LinearSolve")
# Pkg.Registry.rm("General")
# Pkg.Registry.add("General")
# Pkg.update()
# Pkg.add("RecursiveArrayTools")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.10/Project.toml`
#   No Changes to `~/.julia/environments/v1.10/Manifest.toml`

# %%
# Pkg.activate("../LinearSolve.jl")
# Pkg.activate(temp=true)
# Pkg.add("LinearSolve")
# Pkg.resolve()
# Pkg.test("LinearSolve")

Pkg.activate("../LinearSolve.jl")
Pkg.instantiate()

# using Test

# Pkg.add("RecursiveFactorization")
# include("../LinearSolve.jl/test/default_algs.jl")
# Pkg.test()
# using LinearSolve, Test
# include("test/interface.jl")
# include("test/utils.jl")
# include("test/default_solve.jl")
# Out:
#   Activating project at `~/CSCI3656-NumComp/LinearSolve.jl`

# %%
Pkg.test("LinearSolve")
# Out:
#      Testing LinearSolve
#       Status `/tmp/jl_YGNhEG/Project.toml`
#   [9b6a8646] AllocCheck v0.2.2
#   [4c88cf16] Aqua v0.8.14
#   [4fba245c] ArrayInterface v7.20.0
#   [aae01518] BandedMatrices v1.9.5
#   [0a1fb500] BlockDiagonals v0.2.0
#   [d360d2e6] ChainRulesCore v1.26.0
#   [60701a23] CliqueTrees v1.12.1
#   [2569d6c7] ConcreteStructs v0.2.3
#   [ffbed154] DocStringExtensions v0.9.5
#   [4e289a0a] EnumX v1.0.5
#   [7d51a73a] ExplicitImports v1.13.2
#   [9d29842c] FastAlmostBandedMatrices v0.1.5
#   [29a986be] FastLapackInterface v2.0.4
#   [6a86dc24] FiniteDiff v2.28.1
#   [f6369f11] ForwardDiff v1.2.1
#   [46192b85] GPUArraysCore v0.2.0
#   [b5ffcf37] HYPRE v1.7.0
#   [42fd0dbc] IterativeSolvers v0.9.4
#   [ba0b0d4f] Krylov v0.10.2
#   [0b1a1467] KrylovKit v0.10.1
#   [45d422c2] KrylovPreconditioners v0.3.6
#   [5078a376] LazyArrays v2.8.0
#   [7ed4a6bd] LinearSolve v3.43.0 `~/CSCI3656-NumComp/LinearSolve.jl`
#   [da04e1cc] MPI v0.20.23
#   [bdf0d083] MultiFloats v2.3.0
# ...

# %%
import LinearSolve as LS
import LinearAlgebra as LA

n = 4
A = rand(n, n)
b1 = rand(n);
b2 = rand(n);
prob = LS.LinearProblem(A, b1)
@show A

linsolve = LS.init(prob)
sol1 = LS.solve!(linsolve)

# %%
A = [1 2; 3 4]
