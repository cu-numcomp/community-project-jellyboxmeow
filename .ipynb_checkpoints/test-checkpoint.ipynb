# %%
using Pkg
# Pkg.add("LinearSolve")
# Pkg.Registry.rm("General")
# Pkg.Registry.add("General")
# Pkg.update()
# Pkg.add("RecursiveArrayTools")

# %%
# Pkg.activate("../LinearSolve.jl")
Pkg.activate(temp=true)
# Pkg.add("LinearSolve")
# Pkg.test("LinearSolve")

Pkg.activate("../LinearSolve.jl")
Pkg.instantiate()

using Test

Pkg.add("RecursiveFactorization")
include("../LinearSolve.jl/test/default_algs.jl")
# Pkg.test()
# using LinearSolve, Test
# include("test/interface.jl")
# include("test/utils.jl")
# include("test/default_solve.jl")
# Out:
#   Activating new project at `/tmp/jl_NDpKzX`
#   Activating project at `~/CSCI3656-NumComp/LinearSolve.jl`
#    Resolving package versions...
#     Updating `~/CSCI3656-NumComp/LinearSolve.jl/Project.toml`
#   [f2c3362d] + RecursiveFactorization v0.2.24
#     Updating `~/CSCI3656-NumComp/LinearSolve.jl/Manifest.toml`
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.6
#   [2a0fbf3d] + CPUSummary v0.2.7
#   [fb6a15b2] + CloseOpenIntervals v0.1.13
#   [f70d9fcc] + CommonWorldInvalidations v1.0.0
#   [adafc99b] + CpuId v0.3.1
#   [3e5b6fbb] + HostCPUFeatures v0.1.17
#   [615f187c] + IfElse v0.1.1
#   [10f19ff3] + LayoutPointers v0.1.17
#   [bdcacae8] + LoopVectorization v0.12.173
#   [d125e4d3] + ManualMemory v0.1.8
#   [6fe1bfb0] + OffsetArrays v1.17.0
#   [f517fe37] + Polyester v0.7.18
#   [1d0040c9] + PolyesterWeave v0.2.2
#   [f2c3362d] + RecursiveFactorization v0.2.24
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.43
#   [431bcebd] + SciMLPublic v1.0.0
#   [bd59d7e1] + SparseBandedMatrices v1.0.0
#   [aedffcd0] + Static v1.3.0
#   [0d7ed370] + StaticArrayInterface v1.8.0
#   [7792a7ef] + StrideArraysCore v0.5.8
#   [8290d209] + ThreadingUtilities v0.5.5
#   [d5829a12] + TriangularSolve v0.2.1
#   [3d5dd08c] + VectorizationBase v0.21.72
#   [33b4df10] + VectorizedRNG v0.2.25
# Precompiling project...
#   ✓ SIMDTypes
#   ✓ CpuId
#   ✓ IfElse
#   ✓ SparseBandedMatrices
#   ✓ SciMLPublic
#   ✓ ManualMemory
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ✓ Static
#   ✓ ThreadingUtilities
#   ✓ BitTwiddlingConvenienceFunctions
#   ✓ CPUSummary
#   ✓ StaticArrayInterface
#   ✓ HostCPUFeatures
#   ✓ PolyesterWeave
#   ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#   ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ✓ CloseOpenIntervals
#   ✓ LayoutPointers
#   ✓ StrideArraysCore
#   ✓ Polyester
#   ✓ VectorizationBase
#   ✓ SLEEFPirates
#   ✓ VectorizedRNG
#   ✓ VectorizedRNG → VectorizedRNGStaticArraysExt
#   ✓ LoopVectorization
#   ✓ TriangularSolve

# %%
import LinearSolve as LS
import LinearAlgebra as LA

n = 4
A = rand(n, n)
b1 = rand(n);
b2 = rand(n);
prob = LS.LinearProblem(A, b1)
@show A

linsolve = LS.init(prob)
sol1 = LS.solve!(linsolve)

# %%
A = [1 2; 3 4]
